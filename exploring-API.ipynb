# %% [markdown]
# ## Exploring Unsplash API

# %%
import requests

# %%
city = 'London'
state = 'England'
country = 'UK'
api_key = '75888166353b3bceb007d3f435676c70'
api_response = requests.get(f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric")

# %%
api_response.status_code
# Out:
# 200

# %%
data = api_response.json()
# data

# %%
data.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
data['list'][2]
# Out:
# {'dt': 1770897600,
#  'main': {'temp': 7.81,
#   'feels_like': 6.01,
#   'temp_min': 7.81,
#   'temp_max': 7.98,
#   'pressure': 983,
#   'sea_level': 983,
#   'grnd_level': 980,
#   'humidity': 92,
#   'temp_kf': -0.17},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10d'}],
#  'clouds': {'all': 74},
#  'wind': {'speed': 2.81, 'deg': 277, 'gust': 8.17},
#  'visibility': 10000,
#  'pop': 0.2,
#  'rain': {'3h': 0.33},
#  'sys': {'pod': 'd'},
#  'dt_txt': '2026-02-12 12:00:00'}

# %%
data['weather'][0]['icon']
# Out:
# '04n'
