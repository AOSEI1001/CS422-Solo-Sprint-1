# %% [markdown]
# ## Exploring Unsplash API

# %%
import requests

# %%
city = 'London'
state = 'England'
country = 'UK'
api_key = '75888166353b3bceb007d3f435676c70'
api_response = requests.get(f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=imperial")

# %%
api_response.status_code
# Out:
# 200

# %%
data = api_response.json()
# data

# %%
data.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
data['list']
# Out:
# [{'dt': 1771048800,
#   'main': {'temp': 36.09,
#    'feels_like': 29.16,
#    'temp_min': 34.95,
#    'temp_max': 36.09,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1007,
#    'humidity': 75,
#    'temp_kf': 0.63},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 58},
#   'wind': {'speed': 9.24, 'deg': 7, 'gust': 21.32},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-02-14 06:00:00'},
#  {'dt': 1771059600,
#   'main': {'temp': 36.09,
#    'feels_like': 29.43,
#    'temp_min': 35.8,
#    'temp_max': 36.09,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1011,
#    'humidity': 70,
#    'temp_kf': 0.16},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 32},
#   'wind': {'speed': 8.72, 'deg': 355, 'gust': 20.2},
#   'visibility': 10000,
# ...

# %%
data['weather'][0]['icon']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 data['weather'][0]['icon']
#
# KeyError: 'weather'
